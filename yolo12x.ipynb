# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="dwR5PN4WOtIgjCvVMM56")
project = rf.workspace("saharat-yyrhu").project("swimmingxdrowning")
version = project.version(4)
dataset = version.download("yolov12")

# %%
# !pip install -U ultralytics
# !pip install -U ipywidgets
# Out:
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
# ...

# %%
import os
os.environ['WANDB_MODE'] = 'disabled'

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Go to YOLOv8 root folder
import os

target_dir = "/content/drive/MyDrive/DS/YoloV12"

# Create the directory if it doesn't exist
if not os.path.exists(target_dir):
    os.makedirs(target_dir)
    print(f"Created directory: {target_dir}")
else:
    print(f"Directory already exists: {target_dir}")

# Change to the directory
# %cd "{target_dir}"
# Out:
# Created directory: /content/drive/MyDrive/DS/YoloV12
# /content/drive/MyDrive/DS/YoloV12

# %%
# !yolo train data="/content/SwimmingXDrowning-4/data.yaml" model=yolo12x.pt epochs=1000 device=0 batch=8 workers=4 seed=101 patience=300 #resume=True
# Out:
# ...
# 100% 114M/114M [00:00<00:00, 211MB/s]
# Ultralytics 8.3.115 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo train data="/content/SwimmingXDrowning-3/data.yaml" model="yolo12x.pt" epochs=1000 device='0,1' batch=22 workers=22 seed=101 patience=300 #resume=True

# %%
# !yolo train data="/content/SwimmingXDrowning-3/data.yaml" model="/content/drive1/MyDrive/DS-OLD/YoloV12-Qatar/runs/detect/train5/weights/last.pt" epochs=1000 device=0 batch=8 workers=4 seed=101 patience=300 resume=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.114 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.113 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
